# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn 
import seaborn as sns

# %%
url_train = '../data/train.csv'

training_data_df = pd.read_csv(url_train)

# %%
training_data_df.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
training_data_df.duplicated().sum()
# Out:
# 0

# %%
training_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
training_data_df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data_x = training_data_df.drop(['price_range'], axis=1)

# %%
data_y = training_data_df['price_range'].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.25, random_state=0)
print ('Train set:\t', x_train.shape,  y_train.shape)
print ('Test set:\t', x_test.shape,  y_test.shape)
# Out:
# Train set:	 (1500, 20) (1500, 1)
# Test set:	 (500, 20) (500, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn =  KNeighborsClassifier(n_neighbors = 10)
knn.fit(x_train, y_train)
# Out:
# /Users/zx/miniconda3/envs/FSAML/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(x_test,y_test)
# Out:
# 0.946

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_pred = knn.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       124
#            1       0.95      0.95      0.95       110
#            2       0.91      0.92      0.91       125
#            3       0.97      0.92      0.95       141
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500

# %%
from sklearn.neighbors import KNeighborsClassifier

globalRecall = 0
optimalK= 0

for i in range(1,200):

    #print("value of K: ",i)
    knn_prueba = {'classifier': KNeighborsClassifier(n_neighbors = i, metric = 'euclidean')}
    knn_prueba['classifier'].fit(X_train, y_train)

    ## Probability of cancer:
    knn_prueba['y_proba'] = knn_prueba['classifier'].predict_proba(X_test)
    knn_prueba['y_proba'][:10]

    # Storing the the probabilities for the positive class in a separate variable
    knn_prueba['y_proba_positive'] = knn_prueba['y_proba'][:,1]

    # Prediction of the class and comparison with the true one:
    knn_prueba['y_pred'] = knn_prueba['classifier'].predict(X_test)

    knn_prueba['metrics'] = compute_metrics(knn_prueba, y_test,False)

    a = knn_prueba['metrics']["Recall"][0]
    if a>globalRecall:
        globalRecall=a
        optimalK = i
        #print("ENTROOOO"*3)

    #print('-' * 80)

print("The optimal K is: ",optimalK," with an Recall of: ",globalRecall)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/zx/Desktop/DSA_Data_Alliance_proyect/notebooks/mobile-price-modeling.ipynb Cell 14' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/zx/Desktop/DSA_Data_Alliance_proyect/notebooks/mobile-price-modeling.ipynb#ch0000013?line=5'>6</a> for i in range(1,200):
#       <a href='vscode-notebook-cell:/Users/zx/Desktop/DSA_Data_Alliance_proyect/notebooks/mobile-price-modeling.ipynb#ch0000013?line=6'>7</a>
#       <a href='vscode-notebook-cell:/Users/zx/Desktop/DSA_Data_Alliance_proyect/notebooks/mobile-price-modeling.ipynb#ch0000013?line=7'>8</a>     #print("value of K: ",i)
#       <a href='vscode-notebook-cell:/Users/zx/Desktop/DSA_Data_Alliance_proyect/notebooks/mobile-price-modeling.ipynb#ch0000013?line=8'>9</a>     knn_prueba = {'classifier': KNeighborsClassifier(n_neighbors = i, metric = 'euclidean')}
# ...
